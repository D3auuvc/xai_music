# %% [markdown]
# ## Read result json file

# %%
import pandas as pd

_JSON_FILE = rf'result.json'
df = pd.read_json(_JSON_FILE)

data = df.T

data
# Out:
#                                                         instrumrnt       key  \
# HighwayToHell_solo_AcousticGuitar_original          AcousticGuitar  original
# HighwayToHell_solo_AcousticGuitar_original_C#major  AcousticGuitar   C#major
# HighwayToHell_solo_AcousticGuitar_original_Cmajor   AcousticGuitar    Cmajor
# HighwayToHell_solo_AcousticGuitar_original_E-major  AcousticGuitar   E-major
# HighwayToHell_solo_AcousticGuitar_original_Emajor   AcousticGuitar    Emajor
# ...                                                            ...       ...
# HighwayToHell_solo_Xylophone_x150_C#major                Xylophone   C#major
# HighwayToHell_solo_Xylophone_x150_Cmajor                 Xylophone    Cmajor
# HighwayToHell_solo_Xylophone_x150_Dmajor                 Xylophone    Dmajor
# HighwayToHell_solo_Xylophone_x150_E-major                Xylophone   E-major
# HighwayToHell_solo_Xylophone_x150_Emajor                 Xylophone    Emajor
#
#                                                                                                  tags  \
# HighwayToHell_solo_AcousticGuitar_original          [guitar, slow, classical, strings, harp, quiet...
# HighwayToHell_solo_AcousticGuitar_original_C#major  [guitar, slow, classical, strings, harp, quiet...
# HighwayToHell_solo_AcousticGuitar_original_Cmajor   [guitar, slow, harp, strings, classical, quiet...
# HighwayToHell_solo_AcousticGuitar_original_E-major  [guitar, slow, classical, harp, strings, quiet...
# HighwayToHell_solo_AcousticGuitar_original_Emajor   [guitar, slow, classical, strings, harp, quiet...
# ...                                                                                               ...
# HighwayToHell_solo_Xylophone_x150_C#major           [guitar, quiet, slow, strings, classical, harp...
# HighwayToHell_solo_Xylophone_x150_Cmajor            [guitar, quiet, slow, strings, classical, harp...
# HighwayToHell_solo_Xylophone_x150_Dmajor            [guitar, quiet, slow, strings, classical, harp...
# HighwayToHell_solo_Xylophone_x150_E-major           [guitar, quiet, slow, strings, classical, harp...
# HighwayToHell_solo_Xylophone_x150_Emajor            [guitar, quiet, slow, strings, classical, harp...
#
#                                                        tempo
# HighwayToHell_solo_AcousticGuitar_original          original
# HighwayToHell_solo_AcousticGuitar_original_C#major  original
# HighwayToHell_solo_AcousticGuitar_original_Cmajor   original
# HighwayToHell_solo_AcousticGuitar_original_E-major  original
# HighwayToHell_solo_AcousticGuitar_original_Emajor   original
# ...                                                      ...
# HighwayToHell_solo_Xylophone_x150_C#major               x150
# HighwayToHell_solo_Xylophone_x150_Cmajor                x150
# HighwayToHell_solo_Xylophone_x150_Dmajor                x150
# HighwayToHell_solo_Xylophone_x150_E-major               x150
# HighwayToHell_solo_Xylophone_x150_Emajor                x150
#
# [500 rows x 4 columns]

# %% [markdown]
# ## Categorize data by instrument

# %%
instruments = data.instrumrnt.unique().tolist()

instrument_dict = dict()

for i in instruments:
    instrument_dict[i] = data.loc[data['instrumrnt'] == i]


Xylophone = instrument_dict['Xylophone']

Xylophone
# Out:
#                                               instrumrnt       key  \
# HighwayToHell_solo_Xylophone_original          Xylophone  original
# HighwayToHell_solo_Xylophone_original_C#major  Xylophone   C#major
# HighwayToHell_solo_Xylophone_original_Cmajor   Xylophone    Cmajor
# HighwayToHell_solo_Xylophone_original_E-major  Xylophone   E-major
# HighwayToHell_solo_Xylophone_original_Emajor   Xylophone    Emajor
# HighwayToHell_solo_Xylophone_x050_C#major      Xylophone   C#major
# HighwayToHell_solo_Xylophone_x050_Cmajor       Xylophone    Cmajor
# HighwayToHell_solo_Xylophone_x050_Dmajor       Xylophone    Dmajor
# HighwayToHell_solo_Xylophone_x050_E-major      Xylophone   E-major
# HighwayToHell_solo_Xylophone_x050_Emajor       Xylophone    Emajor
# HighwayToHell_solo_Xylophone_x075_C#major      Xylophone   C#major
# HighwayToHell_solo_Xylophone_x075_Cmajor       Xylophone    Cmajor
# HighwayToHell_solo_Xylophone_x075_Dmajor       Xylophone    Dmajor
# HighwayToHell_solo_Xylophone_x075_E-major      Xylophone   E-major
# HighwayToHell_solo_Xylophone_x075_Emajor       Xylophone    Emajor
# HighwayToHell_solo_Xylophone_x125_C#major      Xylophone   C#major
# HighwayToHell_solo_Xylophone_x125_Cmajor       Xylophone    Cmajor
# HighwayToHell_solo_Xylophone_x125_Dmajor       Xylophone    Dmajor
# HighwayToHell_solo_Xylophone_x125_E-major      Xylophone   E-major
# HighwayToHell_solo_Xylophone_x125_Emajor       Xylophone    Emajor
# HighwayToHell_solo_Xylophone_x150_C#major      Xylophone   C#major
# HighwayToHell_solo_Xylophone_x150_Cmajor       Xylophone    Cmajor
# HighwayToHell_solo_Xylophone_x150_Dmajor       Xylophone    Dmajor
# HighwayToHell_solo_Xylophone_x150_E-major      Xylophone   E-major
# HighwayToHell_solo_Xylophone_x150_Emajor       Xylophone    Emajor
#
#                                                                                             tags  \
# HighwayToHell_solo_Xylophone_original          [guitar, quiet, slow, strings, classical, harp...
# HighwayToHell_solo_Xylophone_original_C#major  [guitar, quiet, slow, strings, classical, harp...
# HighwayToHell_solo_Xylophone_original_Cmajor   [guitar, quiet, slow, strings, classical, soft...
# HighwayToHell_solo_Xylophone_original_E-major  [guitar, quiet, slow, strings, harp, classical...
# HighwayToHell_solo_Xylophone_original_Emajor   [guitar, quiet, slow, strings, harp, classical...
# HighwayToHell_solo_Xylophone_x050_C#major      [electronic, techno, quiet, slow, synth, guita...
# HighwayToHell_solo_Xylophone_x050_Cmajor       [electronic, quiet, techno, slow, strings, syn...
# HighwayToHell_solo_Xylophone_x050_Dmajor       [electronic, techno, quiet, slow, synth, strin...
# HighwayToHell_solo_Xylophone_x050_E-major      [electronic, techno, quiet, slow, synth, strin...
# HighwayToHell_solo_Xylophone_x050_Emajor       [electronic, techno, quiet, slow, synth, strin...
# HighwayToHell_solo_Xylophone_x075_C#major      [guitar, quiet, slow, strings, classical, harp...
# HighwayToHell_solo_Xylophone_x075_Cmajor       [quiet, guitar, slow, strings, classical, elec...
# HighwayToHell_solo_Xylophone_x075_Dmajor       [guitar, quiet, slow, strings, classical, elec...
# HighwayToHell_solo_Xylophone_x075_E-major      [guitar, quiet, slow, strings, electronic, cla...
# HighwayToHell_solo_Xylophone_x075_Emajor       [quiet, guitar, slow, strings, classical, harp...
# HighwayToHell_solo_Xylophone_x125_C#major      [guitar, quiet, slow, strings, classical, harp...
# HighwayToHell_solo_Xylophone_x125_Cmajor       [guitar, quiet, slow, classical, strings, harp...
# HighwayToHell_solo_Xylophone_x125_Dmajor       [guitar, quiet, slow, strings, classical, harp...
# HighwayToHell_solo_Xylophone_x125_E-major      [guitar, quiet, slow, harp, strings, classical...
# HighwayToHell_solo_Xylophone_x125_Emajor       [guitar, quiet, slow, harp, classical, strings...
# HighwayToHell_solo_Xylophone_x150_C#major      [guitar, quiet, slow, strings, classical, harp...
# HighwayToHell_solo_Xylophone_x150_Cmajor       [guitar, quiet, slow, strings, classical, harp...
# HighwayToHell_solo_Xylophone_x150_Dmajor       [guitar, quiet, slow, strings, classical, harp...
# HighwayToHell_solo_Xylophone_x150_E-major      [guitar, quiet, slow, strings, classical, harp...
# HighwayToHell_solo_Xylophone_x150_Emajor       [guitar, quiet, slow, strings, classical, harp...
#
#                                                   tempo
# HighwayToHell_solo_Xylophone_original          original
# HighwayToHell_solo_Xylophone_original_C#major  original
# HighwayToHell_solo_Xylophone_original_Cmajor   original
# HighwayToHell_solo_Xylophone_original_E-major  original
# HighwayToHell_solo_Xylophone_original_Emajor   original
# HighwayToHell_solo_Xylophone_x050_C#major          x050
# HighwayToHell_solo_Xylophone_x050_Cmajor           x050
# HighwayToHell_solo_Xylophone_x050_Dmajor           x050
# HighwayToHell_solo_Xylophone_x050_E-major          x050
# HighwayToHell_solo_Xylophone_x050_Emajor           x050
# HighwayToHell_solo_Xylophone_x075_C#major          x075
# HighwayToHell_solo_Xylophone_x075_Cmajor           x075
# HighwayToHell_solo_Xylophone_x075_Dmajor           x075
# HighwayToHell_solo_Xylophone_x075_E-major          x075
# HighwayToHell_solo_Xylophone_x075_Emajor           x075
# HighwayToHell_solo_Xylophone_x125_C#major          x125
# HighwayToHell_solo_Xylophone_x125_Cmajor           x125
# HighwayToHell_solo_Xylophone_x125_Dmajor           x125
# HighwayToHell_solo_Xylophone_x125_E-major          x125
# HighwayToHell_solo_Xylophone_x125_Emajor           x125
# HighwayToHell_solo_Xylophone_x150_C#major          x150
# HighwayToHell_solo_Xylophone_x150_Cmajor           x150
# HighwayToHell_solo_Xylophone_x150_Dmajor           x150
# HighwayToHell_solo_Xylophone_x150_E-major          x150
# HighwayToHell_solo_Xylophone_x150_Emajor           x150

# %% [markdown]
# ## Preprocessing data
#
# - one hot encoding

# %%
# one hot encoding

ohe_df = Xylophone.drop('tags', 1).join(
    Xylophone.tags.str.join('|').str.get_dummies())

ohe_df.drop(ohe_df.columns[[0]], axis=1, inplace=True)
ohe_df.groupby(['key', 'tempo']).sum()
# Out:
#                    ambient  beat  classical  drums  electronic  guitar  harp  \
# key      tempo
# C#major  original        0     0          1      0           1       1     1
#          x050            1     1          0      0           1       1     0
#          x075            0     0          1      1           1       1     1
#          x125            0     0          1      0           0       1     1
#          x150            0     0          1      0           0       1     1
# Cmajor   original        0     0          1      1           1       1     1
#          x050            0     1          0      0           1       1     0
#          x075            0     1          1      1           1       1     0
#          x125            0     0          1      1           0       1     1
#          x150            0     0          1      1           0       1     1
# Dmajor   x050            1     1          0      0           1       1     0
#          x075            0     0          1      0           1       1     1
#          x125            0     0          1      0           0       1     1
#          x150            0     0          1      0           0       1     1
# E-major  original        0     0          1      0           1       1     1
#          x050            1     1          0      0           1       0     0
#          x075            0     0          1      0           1       1     1
#          x125            0     0          1      0           0       1     1
#          x150            0     0          1      0           1       1     1
# Emajor   original        0     0          1      0           1       1     1
#          x050            1     0          0      0           1       1     0
#          x075            0     0          1      0           1       1     1
#          x125            0     0          1      0           0       1     1
#          x150            0     0          1      0           0       1     1
# original original        0     0          1      0           1       1     1
#
#                    no vocal  no vocals  piano  quiet  slow  soft  strings  \
# key      tempo
# C#major  original         1          1      0      1     1     1        1
#          x050             0          1      0      1     1     0        1
#          x075             0          1      0      1     1     1        1
#          x125             1          1      1      1     1     1        1
#          x150             1          1      1      1     1     1        1
# Cmajor   original         0          1      0      1     1     1        1
#          x050             1          1      0      1     1     0        1
#          x075             0          1      0      1     1     1        1
#          x125             0          1      1      1     1     1        1
#          x150             1          1      0      1     1     1        1
# Dmajor   x050             0          1      0      1     1     0        1
#          x075             1          1      0      1     1     1        1
#          x125             1          1      1      1     1     1        1
#          x150             1          1      1      1     1     1        1
# E-major  original         1          1      0      1     1     1        1
#          x050             1          1      0      1     1     0        1
#          x075             0          1      0      1     1     1        1
#          x125             1          1      1      1     1     1        1
#          x150             1          1      0      1     1     1        1
# Emajor   original         1          1      0      1     1     1        1
#          x050             1          1      0      1     1     0        1
#          x075             0          1      0      1     1     1        1
#          x125             1          1      1      1     1     1        1
#          x150             1          1      1      1     1     1        1
# original original         1          1      0      1     1     1        1
#
#                    synth  techno
# key      tempo
# C#major  original      0       0
#          x050          1       1
#          x075          0       0
#          x125          0       0
#          x150          0       0
# Cmajor   original      0       0
#          x050          1       1
#          x075          0       0
#          x125          0       0
#          x150          0       0
# Dmajor   x050          1       1
#          x075          0       0
#          x125          0       0
#          x150          0       0
# E-major  original      0       0
#          x050          1       1
#          x075          0       1
#          x125          0       0
#          x150          0       0
# Emajor   original      0       0
#          x050          1       1
#          x075          0       1
#          x125          0       0
#          x150          0       0
# original original      0       0

# %%
group_ohe_df = ohe_df.groupby(['key']).sum()
group_ohe_df
# Out:
#           ambient  beat  classical  drums  electronic  guitar  harp  no vocal  \
# key
# C#major         1     1          4      1           3       5     4         3
# Cmajor          0     2          4      4           3       5     3         2
# Dmajor          1     1          3      0           2       4     3         3
# E-major         1     1          4      0           4       4     4         4
# Emajor          1     0          4      0           3       5     4         4
# original        0     0          1      0           1       1     1         1
#
#           no vocals  piano  quiet  slow  soft  strings  synth  techno
# key
# C#major           5      2      5     5     4        5      1       1
# Cmajor            5      1      5     5     4        5      1       1
# Dmajor            4      2      4     4     3        4      1       1
# E-major           5      1      5     5     4        5      1       2
# Emajor            5      2      5     5     4        5      1       2
# original          1      0      1     1     1        1      0       0

# %%
from matplotlib import ticker
import matplotlib.pyplot as plt


def plot_result(group_ohe_df):
    fig, ax = plt.subplots()
    fig.set_figwidth(20)

    arr = group_ohe_df.to_numpy()
    key, tag = arr.shape

    x_lables_lits = [col for col in group_ohe_df.columns]
    y_lables_lits = group_ohe_df.index.tolist()

    ax.matshow(arr, cmap=plt.cm.Blues)
    ax.set_xlabel('tag')
    ax.set_ylabel(group_ohe_df.index.name)
    ax.xaxis.set_ticklabels([''] + x_lables_lits, rotation=90)
    ax.yaxis.set_ticklabels([''] + y_lables_lits)
    ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
    ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

    for i in range(tag):
        for j in range(key):
            c = arr[j, i]
            ax.text(i, j, str(c), va='center', ha='center')

    plt.show()


plot_result(group_ohe_df)
# Out:
# /Users/dc/miniconda3/envs/env36/lib/python3.6/site-packages/ipykernel_launcher.py:18: UserWarning: FixedFormatter should only be used together with FixedLocator
# /Users/dc/miniconda3/envs/env36/lib/python3.6/site-packages/ipykernel_launcher.py:19: UserWarning: FixedFormatter should only be used together with FixedLocator

# %%
ohe_df.groupby(['tempo', 'key']).sum()
# Out:
#                    ambient  beat  classical  drums  electronic  guitar  harp  \
# tempo    key
# original C#major         0     0          1      0           1       1     1
#          Cmajor          0     0          1      1           1       1     1
#          E-major         0     0          1      0           1       1     1
#          Emajor          0     0          1      0           1       1     1
#          original        0     0          1      0           1       1     1
# x050     C#major         1     1          0      0           1       1     0
#          Cmajor          0     1          0      0           1       1     0
#          Dmajor          1     1          0      0           1       1     0
#          E-major         1     1          0      0           1       0     0
#          Emajor          1     0          0      0           1       1     0
# x075     C#major         0     0          1      1           1       1     1
#          Cmajor          0     1          1      1           1       1     0
#          Dmajor          0     0          1      0           1       1     1
#          E-major         0     0          1      0           1       1     1
#          Emajor          0     0          1      0           1       1     1
# x125     C#major         0     0          1      0           0       1     1
#          Cmajor          0     0          1      1           0       1     1
#          Dmajor          0     0          1      0           0       1     1
#          E-major         0     0          1      0           0       1     1
#          Emajor          0     0          1      0           0       1     1
# x150     C#major         0     0          1      0           0       1     1
#          Cmajor          0     0          1      1           0       1     1
#          Dmajor          0     0          1      0           0       1     1
#          E-major         0     0          1      0           1       1     1
#          Emajor          0     0          1      0           0       1     1
#
#                    no vocal  no vocals  piano  quiet  slow  soft  strings  \
# tempo    key
# original C#major          1          1      0      1     1     1        1
#          Cmajor           0          1      0      1     1     1        1
#          E-major          1          1      0      1     1     1        1
#          Emajor           1          1      0      1     1     1        1
#          original         1          1      0      1     1     1        1
# x050     C#major          0          1      0      1     1     0        1
#          Cmajor           1          1      0      1     1     0        1
#          Dmajor           0          1      0      1     1     0        1
#          E-major          1          1      0      1     1     0        1
#          Emajor           1          1      0      1     1     0        1
# x075     C#major          0          1      0      1     1     1        1
#          Cmajor           0          1      0      1     1     1        1
#          Dmajor           1          1      0      1     1     1        1
#          E-major          0          1      0      1     1     1        1
#          Emajor           0          1      0      1     1     1        1
# x125     C#major          1          1      1      1     1     1        1
#          Cmajor           0          1      1      1     1     1        1
#          Dmajor           1          1      1      1     1     1        1
#          E-major          1          1      1      1     1     1        1
#          Emajor           1          1      1      1     1     1        1
# x150     C#major          1          1      1      1     1     1        1
#          Cmajor           1          1      0      1     1     1        1
#          Dmajor           1          1      1      1     1     1        1
#          E-major          1          1      0      1     1     1        1
#          Emajor           1          1      1      1     1     1        1
#
#                    synth  techno
# tempo    key
# original C#major       0       0
#          Cmajor        0       0
#          E-major       0       0
#          Emajor        0       0
#          original      0       0
# x050     C#major       1       1
#          Cmajor        1       1
#          Dmajor        1       1
#          E-major       1       1
#          Emajor        1       1
# x075     C#major       0       0
#          Cmajor        0       0
#          Dmajor        0       0
#          E-major       0       1
#          Emajor        0       1
# x125     C#major       0       0
#          Cmajor        0       0
#          Dmajor        0       0
#          E-major       0       0
#          Emajor        0       0
# x150     C#major       0       0
#          Cmajor        0       0
#          Dmajor        0       0
#          E-major       0       0
#          Emajor        0       0

# %%
groupby_tempo_ohe_df = ohe_df.groupby(['tempo']).sum()
groupby_tempo_ohe_df
# Out:
#           ambient  beat  classical  drums  electronic  guitar  harp  no vocal  \
# tempo
# original        0     0          5      1           5       5     5         4
# x050            4     4          0      0           5       4     0         3
# x075            0     1          5      2           5       5     4         1
# x125            0     0          5      1           0       5     5         4
# x150            0     0          5      1           1       5     5         5
#
#           no vocals  piano  quiet  slow  soft  strings  synth  techno
# tempo
# original          5      0      5     5     5        5      0       0
# x050              5      0      5     5     0        5      5       5
# x075              5      0      5     5     5        5      0       2
# x125              5      5      5     5     5        5      0       0
# x150              5      3      5     5     5        5      0       0

# %%
plot_result(groupby_tempo_ohe_df)
# Out:
# /Users/dc/miniconda3/envs/env36/lib/python3.6/site-packages/ipykernel_launcher.py:18: UserWarning: FixedFormatter should only be used together with FixedLocator
# /Users/dc/miniconda3/envs/env36/lib/python3.6/site-packages/ipykernel_launcher.py:19: UserWarning: FixedFormatter should only be used together with FixedLocator

# %%
grouped_df = ohe_df.groupby('key')
grouped_df.describe()
# Out:
#          ambient                                            beat        ...  \
#            count  mean       std  min  25%  50%   75%  max count  mean  ...
# key                                                                     ...
# C#major      5.0  0.20  0.447214  0.0  0.0  0.0  0.00  1.0   5.0  0.20  ...
# Cmajor       5.0  0.00  0.000000  0.0  0.0  0.0  0.00  0.0   5.0  0.40  ...
# Dmajor       4.0  0.25  0.500000  0.0  0.0  0.0  0.25  1.0   4.0  0.25  ...
# E-major      5.0  0.20  0.447214  0.0  0.0  0.0  0.00  1.0   5.0  0.20  ...
# Emajor       5.0  0.20  0.447214  0.0  0.0  0.0  0.00  1.0   5.0  0.00  ...
# original     1.0  0.00       NaN  0.0  0.0  0.0  0.00  0.0   1.0  0.00  ...
#
#          synth      techno
#            75%  max  count  mean       std  min  25%  50%   75%  max
# key
# C#major   0.00  1.0    5.0  0.20  0.447214  0.0  0.0  0.0  0.00  1.0
# Cmajor    0.00  1.0    5.0  0.20  0.447214  0.0  0.0  0.0  0.00  1.0
# Dmajor    0.25  1.0    4.0  0.25  0.500000  0.0  0.0  0.0  0.25  1.0
# E-major   0.00  1.0    5.0  0.40  0.547723  0.0  0.0  0.0  1.00  1.0
# Emajor    0.00  1.0    5.0  0.40  0.547723  0.0  0.0  0.0  1.00  1.0
# original  0.00  0.0    1.0  0.00       NaN  0.0  0.0  0.0  0.00  0.0
#
# [6 rows x 128 columns]

# %%
def plot_multi_result(groupby_dict, size):
    fig, ax = plt.subplots(size, 1, figsize=(100, 100), gridspec_kw={
        'wspace': 0.4,
        'hspace': 0.8})

    idx = 0
    for instrumrnt, group_ohe_df in groupby_dict.items():
        arr = group_ohe_df.to_numpy()
        key, tag = arr.shape
        groupby = group_ohe_df.index.name
        fig.suptitle(f'Group by {groupby}')

        x_lables_lits = [col for col in group_ohe_df.columns]
        y_lables_lits = group_ohe_df.index.tolist()

        ax[idx].matshow(arr, cmap=plt.cm.Blues)

        ax[idx].set_xlabel('tag')
        ax[idx].set_title(instrumrnt)
        ax[idx].set_ylabel(groupby)

        ax[idx].xaxis.set_ticklabels([''] + x_lables_lits, rotation=90)
        ax[idx].yaxis.set_ticklabels([''] + y_lables_lits)
        ax[idx].xaxis.set_major_locator(ticker.MultipleLocator(1))
        ax[idx].yaxis.set_major_locator(ticker.MultipleLocator(1))

        for i in range(tag):
            for j in range(key):
                c = arr[j, i]
                ax[idx].text(i, j, str(c), va='center', ha='center')
        idx += 1

    plt.show()

# %%
# By key
groupby_key_dict = dict()

for key, value in instrument_dict.items():
    ohe_df = value.drop('tags', 1).join(
        value.tags.str.join('|').str.get_dummies())
    ohe_df.drop(ohe_df.columns[[0]], axis=1, inplace=True)
    groupby_key_dict[key] = ohe_df.groupby(['key']).sum()


plot_multi_result(groupby_key_dict, len(groupby_key_dict))
# Out:
# /Users/dc/miniconda3/envs/env36/lib/python3.6/site-packages/ipykernel_launcher.py:22: UserWarning: FixedFormatter should only be used together with FixedLocator
# /Users/dc/miniconda3/envs/env36/lib/python3.6/site-packages/ipykernel_launcher.py:23: UserWarning: FixedFormatter should only be used together with FixedLocator

# %%
# By tempo
groupby_tempo_dict = dict()

for key, value in instrument_dict.items():
    ohe_df = value.drop('tags', 1).join(
        value.tags.str.join('|').str.get_dummies())
    ohe_df.drop(ohe_df.columns[[0]], axis=1, inplace=True)
    groupby_tempo_dict[key] = ohe_df.groupby(['tempo']).sum()


plot_multi_result(groupby_tempo_dict, len(groupby_tempo_dict))
# Out:
# /Users/dc/miniconda3/envs/env36/lib/python3.6/site-packages/ipykernel_launcher.py:22: UserWarning: FixedFormatter should only be used together with FixedLocator
# /Users/dc/miniconda3/envs/env36/lib/python3.6/site-packages/ipykernel_launcher.py:23: UserWarning: FixedFormatter should only be used together with FixedLocator

# %% [markdown]
# ## Category by Key

# %%
# Categorize function
# features: instrumrnt, tempo

def categorize(data, feature):
    categorized_df = data[feature].unique().tolist()
    categorized_dict = dict()
    for i in categorized_df:
        categorized_dict[i] = data.loc[data[feature] == i]

    return categorized_dict


categorized_dict = categorize(data, 'key')
categorized_dict['C#major']
# Out:
#                                                         instrumrnt      key  \
# HighwayToHell_solo_AcousticGuitar_original_C#major  AcousticGuitar  C#major
# HighwayToHell_solo_AcousticGuitar_x050_C#major      AcousticGuitar  C#major
# HighwayToHell_solo_AcousticGuitar_x075_C#major      AcousticGuitar  C#major
# HighwayToHell_solo_AcousticGuitar_x125_C#major      AcousticGuitar  C#major
# HighwayToHell_solo_AcousticGuitar_x150_C#major      AcousticGuitar  C#major
# ...                                                            ...      ...
# HighwayToHell_solo_Xylophone_original_C#major            Xylophone  C#major
# HighwayToHell_solo_Xylophone_x050_C#major                Xylophone  C#major
# HighwayToHell_solo_Xylophone_x075_C#major                Xylophone  C#major
# HighwayToHell_solo_Xylophone_x125_C#major                Xylophone  C#major
# HighwayToHell_solo_Xylophone_x150_C#major                Xylophone  C#major
#
#                                                                                                  tags  \
# HighwayToHell_solo_AcousticGuitar_original_C#major  [guitar, slow, classical, strings, harp, quiet...
# HighwayToHell_solo_AcousticGuitar_x050_C#major      [guitar, strings, harp, classical, slow, quiet...
# HighwayToHell_solo_AcousticGuitar_x075_C#major      [guitar, slow, classical, strings, harp, quiet...
# HighwayToHell_solo_AcousticGuitar_x125_C#major      [guitar, slow, classical, strings, harp, quiet...
# HighwayToHell_solo_AcousticGuitar_x150_C#major      [guitar, slow, strings, harp, classical, quiet...
# ...                                                                                               ...
# HighwayToHell_solo_Xylophone_original_C#major       [guitar, quiet, slow, strings, classical, harp...
# HighwayToHell_solo_Xylophone_x050_C#major           [electronic, techno, quiet, slow, synth, guita...
# HighwayToHell_solo_Xylophone_x075_C#major           [guitar, quiet, slow, strings, classical, harp...
# HighwayToHell_solo_Xylophone_x125_C#major           [guitar, quiet, slow, strings, classical, harp...
# HighwayToHell_solo_Xylophone_x150_C#major           [guitar, quiet, slow, strings, classical, harp...
#
#                                                        tempo
# HighwayToHell_solo_AcousticGuitar_original_C#major  original
# HighwayToHell_solo_AcousticGuitar_x050_C#major          x050
# HighwayToHell_solo_AcousticGuitar_x075_C#major          x075
# HighwayToHell_solo_AcousticGuitar_x125_C#major          x125
# HighwayToHell_solo_AcousticGuitar_x150_C#major          x150
# ...                                                      ...
# HighwayToHell_solo_Xylophone_original_C#major       original
# HighwayToHell_solo_Xylophone_x050_C#major               x050
# HighwayToHell_solo_Xylophone_x075_C#major               x075
# HighwayToHell_solo_Xylophone_x125_C#major               x125
# HighwayToHell_solo_Xylophone_x150_C#major               x150
#
# [100 rows x 4 columns]

# %%
# By instrumrnt
groupby_instrumrnt_dict = dict()

for key, value in categorized_dict.items():
    ohe_df = value.drop('tags', 1).join(
        value.tags.str.join('|').str.get_dummies())
    # ohe_df.drop(ohe_df.columns[[0]], axis=1, inplace=True)
    groupby_instrumrnt_dict[key] = ohe_df.groupby(['instrumrnt']).sum()

# groupby_instrumrnt_dict['original']
plot_multi_result(groupby_instrumrnt_dict, len(groupby_instrumrnt_dict))
# Out:
# /Users/dc/miniconda3/envs/env36/lib/python3.6/site-packages/ipykernel_launcher.py:22: UserWarning: FixedFormatter should only be used together with FixedLocator
# /Users/dc/miniconda3/envs/env36/lib/python3.6/site-packages/ipykernel_launcher.py:23: UserWarning: FixedFormatter should only be used together with FixedLocator

# %%
# By tempo
groupby_tempo_dict = dict()

for key, value in categorized_dict.items():
    ohe_df = value.drop('tags', 1).join(
        value.tags.str.join('|').str.get_dummies())
    # ohe_df.drop(ohe_df.columns[[0]], axis=1, inplace=True)
    groupby_tempo_dict[key] = ohe_df.groupby(['tempo']).sum()

# groupby_tempo_dict['original']
plot_multi_result(groupby_tempo_dict, len(groupby_tempo_dict))
# Out:
# /Users/dc/miniconda3/envs/env36/lib/python3.6/site-packages/ipykernel_launcher.py:22: UserWarning: FixedFormatter should only be used together with FixedLocator
# /Users/dc/miniconda3/envs/env36/lib/python3.6/site-packages/ipykernel_launcher.py:23: UserWarning: FixedFormatter should only be used together with FixedLocator

# %% [markdown]
# ## Category by tempo

# %%
# features: instrumrnt, key


categorized_dict = categorize(data, 'tempo')
categorized_dict['original']
# Out:
#                                                         instrumrnt       key  \
# HighwayToHell_solo_AcousticGuitar_original          AcousticGuitar  original
# HighwayToHell_solo_AcousticGuitar_original_C#major  AcousticGuitar   C#major
# HighwayToHell_solo_AcousticGuitar_original_Cmajor   AcousticGuitar    Cmajor
# HighwayToHell_solo_AcousticGuitar_original_E-major  AcousticGuitar   E-major
# HighwayToHell_solo_AcousticGuitar_original_Emajor   AcousticGuitar    Emajor
# ...                                                            ...       ...
# HighwayToHell_solo_Xylophone_original                    Xylophone  original
# HighwayToHell_solo_Xylophone_original_C#major            Xylophone   C#major
# HighwayToHell_solo_Xylophone_original_Cmajor             Xylophone    Cmajor
# HighwayToHell_solo_Xylophone_original_E-major            Xylophone   E-major
# HighwayToHell_solo_Xylophone_original_Emajor             Xylophone    Emajor
#
#                                                                                                  tags  \
# HighwayToHell_solo_AcousticGuitar_original          [guitar, slow, classical, strings, harp, quiet...
# HighwayToHell_solo_AcousticGuitar_original_C#major  [guitar, slow, classical, strings, harp, quiet...
# HighwayToHell_solo_AcousticGuitar_original_Cmajor   [guitar, slow, harp, strings, classical, quiet...
# HighwayToHell_solo_AcousticGuitar_original_E-major  [guitar, slow, classical, harp, strings, quiet...
# HighwayToHell_solo_AcousticGuitar_original_Emajor   [guitar, slow, classical, strings, harp, quiet...
# ...                                                                                               ...
# HighwayToHell_solo_Xylophone_original               [guitar, quiet, slow, strings, classical, harp...
# HighwayToHell_solo_Xylophone_original_C#major       [guitar, quiet, slow, strings, classical, harp...
# HighwayToHell_solo_Xylophone_original_Cmajor        [guitar, quiet, slow, strings, classical, soft...
# HighwayToHell_solo_Xylophone_original_E-major       [guitar, quiet, slow, strings, harp, classical...
# HighwayToHell_solo_Xylophone_original_Emajor        [guitar, quiet, slow, strings, harp, classical...
#
#                                                        tempo
# HighwayToHell_solo_AcousticGuitar_original          original
# HighwayToHell_solo_AcousticGuitar_original_C#major  original
# HighwayToHell_solo_AcousticGuitar_original_Cmajor   original
# HighwayToHell_solo_AcousticGuitar_original_E-major  original
# HighwayToHell_solo_AcousticGuitar_original_Emajor   original
# ...                                                      ...
# HighwayToHell_solo_Xylophone_original               original
# HighwayToHell_solo_Xylophone_original_C#major       original
# HighwayToHell_solo_Xylophone_original_Cmajor        original
# HighwayToHell_solo_Xylophone_original_E-major       original
# HighwayToHell_solo_Xylophone_original_Emajor        original
#
# [100 rows x 4 columns]

# %%
# By key
groupby_key_dict = dict()

for key, value in categorized_dict.items():
    ohe_df = value.drop('tags', 1).join(
        value.tags.str.join('|').str.get_dummies())
    # ohe_df.drop(ohe_df.columns[[0]], axis=1, inplace=True)
    groupby_key_dict[key] = ohe_df.groupby(['key']).sum()

# groupby_key_dict['original']
plot_multi_result(groupby_key_dict, len(groupby_key_dict))
# Out:
# /Users/dc/miniconda3/envs/env36/lib/python3.6/site-packages/ipykernel_launcher.py:22: UserWarning: FixedFormatter should only be used together with FixedLocator
# /Users/dc/miniconda3/envs/env36/lib/python3.6/site-packages/ipykernel_launcher.py:23: UserWarning: FixedFormatter should only be used together with FixedLocator

# %%
# By instrumrnt
groupby_instrumrnt_dict = dict()

for key, value in categorized_dict.items():
    ohe_df = value.drop('tags', 1).join(
        value.tags.str.join('|').str.get_dummies())
    # ohe_df.drop(ohe_df.columns[[0]], axis=1, inplace=True)
    groupby_instrumrnt_dict[key] = ohe_df.groupby(['instrumrnt']).sum()

# groupby_instrumrnt_dict['original']
plot_multi_result(groupby_instrumrnt_dict, len(groupby_instrumrnt_dict))
# Out:
# /Users/dc/miniconda3/envs/env36/lib/python3.6/site-packages/ipykernel_launcher.py:22: UserWarning: FixedFormatter should only be used together with FixedLocator
# /Users/dc/miniconda3/envs/env36/lib/python3.6/site-packages/ipykernel_launcher.py:23: UserWarning: FixedFormatter should only be used together with FixedLocator
